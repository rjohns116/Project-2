# %% [markdown]
# -import cleaned files
#
# -restructure/organize the data for maps
#
# -save the map to docs folder
#
# -include link to github pages
#
# -restructure/organize the data for line graphs
#
# -add line graphs
