# %% [markdown]
# #### Canadian Traditional Media Audience Measurement - French and English Viewing Habits

# %% [markdown]
# -notebook for cleaning process
# -saves cleaned files (won't need cleaning.py)
